# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
from datetime import datetime
import os
from configparser import ConfigParser
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from langdetect import detect
import langdetect
from textblob import TextBlob
import calendar
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from prettytable import PrettyTable
from tabulate import tabulate
import numpy as np
from collections import defaultdict
import warnings
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
ds_jobs = pd.read_csv('jobs.csv')
ds_jobs
# Out:
#                                              Job Title  \
# 0                                  Junior Data Analyst
# 1                         Data Science Internship 2025
# 2                                         Data Analyst
# 3                                  Junior Data Analyst
# 4                                 Data Science Manager
# ..                                                 ...
# 657                                      VP of Product
# 658  Product Manager, Payments Cards Modernisation ...
# 659               Marketing Communications Coordinator
# 660                                 Commercial Manager
# 661                             Senior AppOps Engineer
#
#                                   Company Name Salary Estimate   Rating  \
# 0    BENTLEY DRIVERS CLUB SOUTH AUSTRALIA INC.          $54.00      NaN
# 1                                         Visa             NaN  ['3.9']
# 2                       Retro Arcade Solutions             NaN      NaN
# 3                            K2-Tech Solutions          $54.00      NaN
# 4                                       Findex             NaN  ['3.1']
# ..                                         ...             ...      ...
# 657                                 Pet Circle           $136K  ['3.1']
# 658                          Commonwealth Bank           $136K  ['4.0']
# 659               Heritage and People's Choice             NaN      NaN
# 660                   Auto & General Insurance           $189K  ['3.0']
# 661                                    ISG plc            $84K  ['4.2']
#
#                                        Job Description  \
# 0    As a Junior Data Analyst, you will assist in g...
# 1    Company Description\n\nVisa is a world leader ...
# 2    Retro Arcade Solutions is a trailblazer in the...
# 3    As a Junior Data Analyst at K2-Tech Solutions,...
# 4    Drive Data-Driven Success as a Manager at Find...
# ..                                                 ...
# 657  Dogs, cats, budgies and everything in between ...
# 658  Product Manager, Payments Cards Modernisation ...
# 659                                                NaN
# 660  The role\nJoin the Supply Relationship Leaders...
# 661  About ISG\nISG is a dynamic global constructio...
#
#                                                 Skills  \
# 0    Skills: Power BI, Microsoft Excel, Data analys...
# 1    Skills: Power BI, Microsoft Excel, Data analys...
# 2    Skills: Power BI, Microsoft Excel, Data analys...
# 3    Skills: Power BI, Microsoft Excel, Data analys...
# 4    Skills: Power BI, Microsoft Excel, Data analys...
# ..                                                 ...
# 657  Skills: Power BI, Microsoft Excel, Data analys...
# 658  Skills: Power BI, Microsoft Excel, Data analys...
# 659  Skills: Power BI, Microsoft Excel, Data analys...
# 660  Skills: Power BI, Microsoft Excel, Data analys...
# 661  Skills: Power BI, Microsoft Excel, Data analys...
#
#                    Location Founded                                 Industry  \
# 0    Kensington and Norwood     NaN                                      NaN
# 1                    Sydney    1958  Information Technology Support Services
# 2                  Adelaide     NaN                                      NaN
# 3                 Australia     NaN                                      NaN
# 4                 Australia      --            Investment & Asset Management
# ..                      ...     ...                                      ...
# 657                  Sydney    2011                Pet & Pet Supplies Stores
# 658                  Sydney    1911                        Banking & Lending
# 659                Brisbane     NaN                                      NaN
# 660             North Lakes    1999                       Insurance Carriers
# 661                 Ipswich    1989                             Construction
#
#                                    Sector                     Revenue  \
# 0                                     NaN                         NaN
# 1                  Information Technology          $10+ billion (USD)
# 2                                     NaN                         NaN
# 3                                     NaN                         NaN
# 4                                 Finance    Unknown / Non-Applicable
# ..                                    ...                         ...
# 657                  Retail and wholesale  $100 to $500 million (USD)
# 658                               Finance     $5 to $10 billion (USD)
# 659                                   NaN                         NaN
# 660                             Insurance  $100 to $500 million (USD)
# 661  Construction, repair and maintenance    Unknown / Non-Applicable
#
#                        Size     Ownership Type
# 0                       NaN                NaN
# 1          10000+ Employees   Company - Public
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4    1001 to 5000 Employees  Company - Private
# ..                      ...                ...
# 657   501 to 1000 Employees  Company - Private
# 658        10000+ Employees   Company - Public
# 659                     NaN                NaN
# 660  1001 to 5000 Employees  Company - Private
# 661  1001 to 5000 Employees  Company - Private
#
# [662 rows x 13 columns]
